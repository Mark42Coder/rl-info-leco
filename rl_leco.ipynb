# %%
# !git clone https://github.com/kakaobrain/leco.git
# Out:
# Cloning into 'leco'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 146 (delta 25), reused 143 (delta 24), pack-reused 0
# Receiving objects: 100% (146/146), 413.25 KiB | 2.83 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# !ls
# Out:
# BUILD		  WORKSPACE  deepmind	game_scripts	   q3map2
# CONTRIBUTING	  assets     dmlab.lds	lua_tests	   testing
# LICENSE		  assets_oa  docs	public		   third_party
# README.md	  bazel      engine	python
# RELEASE_NOTES.md  data	     examples	python_system.bzl

# %%
# %cd leco
# Out:
# /kaggle/working/leco/leco

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !pip install gym-minigrid==1.0.3
# Out:
# Collecting gym-minigrid==1.0.3
#   Downloading gym_minigrid-1.0.3-py3-none-any.whl.metadata (354 bytes)
# Requirement already satisfied: gym>=0.9.6 in /opt/conda/lib/python3.10/site-packages (from gym-minigrid==1.0.3) (0.26.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from gym-minigrid==1.0.3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.6->gym-minigrid==1.0.3) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.6->gym-minigrid==1.0.3) (0.0.8)
# Downloading gym_minigrid-1.0.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: gym-minigrid
# Successfully installed gym-minigrid-1.0.3

# %%
# !git clone https://github.com/deepmind/lab.git
# Out:
# Cloning into 'lab'...
# remote: Enumerating objects: 7778, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 7778 (delta 65), reused 148 (delta 62), pack-reused 7613
# Receiving objects: 100% (7778/7778), 449.35 MiB | 16.54 MiB/s, done.
# Resolving deltas: 100% (4821/4821), done.
# Updating files: 100% (2602/2602), done.

# %%
# %cd lab
# Out:
# /kaggle/working/leco/leco/lab

# %%
# Update the package list and install required packages
# !sudo apt update
# !sudo apt install apt-transport-https curl gnupg -y
# Out:
# Hit:1 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:2 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:4 http://security.ubuntu.com/ubuntu focal-security InRelease    m
# Hit:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:7 https://storage.googleapis.com/bazel-apt stable InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 73 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# curl is already the newest version (7.68.0-1ubuntu2.22).
# gnupg is already the newest version (2.2.19-3ubuntu2.2).
# apt-transport-https is already the newest version (2.0.10).
# 0 upgraded, 0 newly installed, 0 to remove and 73 not upgraded.

# %%
# Add Bazel's GPG key
# !curl -fsSL https://bazel.build/bazel-release.pub.gpg | gpg --dearmor >bazel-archive-keyring.gpg
# !sudo mv bazel-archive-keyring.gpg /usr/share/keyrings

# Add Bazel's repository
# !echo "deb [arch=amd64 signed-by=/usr/share/keyrings/bazel-archive-keyring.gpg] https://storage.googleapis.com/bazel-apt stable jdk1.8" | sudo tee /etc/apt/sources.list.d/bazel.list
# Out:
# deb [arch=amd64 signed-by=/usr/share/keyrings/bazel-archive-keyring.gpg] https://storage.googleapis.com/bazel-apt stable jdk1.8

# %%
# Update the package list again and install Bazel
# !sudo apt update
# !sudo apt install bazel
# Out:
# Hit:1 https://storage.googleapis.com/bazel-apt stable InRelease
# Hit:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:3 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:4 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 73 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# bazel is already the newest version (7.2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 73 not upgraded.

# %%
# Install the SDL development libraries
# !sudo apt-get update
# !sudo apt-get install -y libsdl2-dev
# Out:
# Hit:1 https://storage.googleapis.com/bazel-apt stable InRelease
# Hit:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:3 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:4 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsdl2-dev is already the newest version (2.0.10+dfsg1-3).
# 0 upgraded, 0 newly installed, 0 to remove and 73 not upgraded.

# %%
# Update package list and install OSMesa development libraries
# !sudo apt-get update
# !sudo apt-get install -y libosmesa6-dev
# Out:
# Hit:1 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:2 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:4 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:7 https://storage.googleapis.com/bazel-apt stable InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libosmesa6-dev is already the newest version (21.2.6-0ubuntu0.1~20.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 73 not upgraded.

# %%
# !sudo apt-get update
# Out:
# Hit:1 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:3 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:7 https://storage.googleapis.com/bazel-apt stable InRelease
# Reading package lists... Done

# %%
# %cd /kaggle/working/leco/leco/lab/content/leco/lab
# Out:
# [Errno 2] No such file or directory: '/content/leco/lab'
# /kaggle/working/leco/leco/lab

# %%
# Update the package list
# !sudo apt-get update

# Install gettext and its development files
# !sudo apt-get install -y gettext
# Install additional build dependencies
# !sudo apt-get install -y build-essential
# !bazel clean --expunge
# Out:
# Hit:1 https://storage.googleapis.com/bazel-apt stable InRelease
# Hit:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:3 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:4 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gettext is already the newest version (0.19.8.1-10build1).
# 0 upgraded, 0 newly installed, 0 to remove and 73 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.8ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 73 not upgraded.
# Starting local Bazel server and connecting to it...
# INFO: Starting clean (this may take a while). Consider using --async if the clean takes more than several minutes.

# %%
# !bazel build -c opt //python/pip_package:build_pip_package
# Out:
# Starting local Bazel server and connecting to it...
# Loading:
# Loading: 0 packages loaded
# Loading: 0 packages loaded
#     Fetching @bazel_tools; Restarting.
# Loading: 0 packages loaded
# Analyzing: target //python/pip_package:build_pip_package (1 packages loaded)
# Analyzing: target //python/pip_package:build_pip_package (1 packages loaded)
# Analyzing: target //python/pip_package:build_pip_package (1 packages loaded, 0\
#  targets configured)
# Analyzing: target //python/pip_package:build_pip_package (4 packages loaded, 5\
#  targets configured)
#     currently loading:
# Analyzing: target //python/pip_package:build_pip_package (5 packages loaded, 5\
#  targets configured)
#     currently loading:
# Analyzing: target //python/pip_package:build_pip_package (6 packages loaded, 9\
#  targets configured)
#     currently loading: @bazel_tools//tools/cpp
# Analyzing: target //python/pip_package:build_pip_package (7 packages loaded, 1\
# 5 targets configured)
#     currently loading: @bazel_tools//tools/cpp ... (2 packages)
#     Fetching @rules_cc; fetching
# Analyzing: target //python/pip_package:build_pip_package (7 packages loaded, 1\
# 5 targets configured)
#     currently loading: @bazel_tools//tools/cpp ... (2 packages)
#     Fetching @rules_cc; fetching
# Analyzing: target //python/pip_package:build_pip_package (7 packages loaded, 1\
# 5 targets configured)
#     currently loading: @bazel_tools//tools/cpp ... (2 packages)
#     Fetching @rules_cc; fetching
#     Fetching https://mirror.bazel.build/...81913a3c40e5948f78719c28152486d.zip
# Analyzing: target //python/pip_package:build_pip_package (7 packages loaded, 1\
# 5 targets configured)
#     currently loading: @bazel_tools//tools/cpp ... (2 packages)
#     Fetching @rules_cc; fetching
#     Fetching https://mirror.bazel.build/...e5948f78719c28152486d.zip; 106,552B
# Analyzing: target //python/pip_package:build_pip_package (7 packages loaded, 1\
# 5 targets configured)
#     currently loading: @bazel_tools//tools/cpp ... (2 packages)
# Analyzing: target //python/pip_package:build_pip_package (12 packages loaded, \
# 17 targets configured)
#     currently loading: @bazel_tools//tools/jdk
#     Fetching @rules_java; fetching
# Analyzing: target //python/pip_package:build_pip_package (15 packages loaded, \
# 42 targets configured)
#     Fetching @local_config_cc; Restarting.
#     Fetching @python_system; fetching
# Analyzing: target //python/pip_package:build_pip_package (15 packages loaded, \
# 42 targets configured)
#     Fetching @local_config_cc; fetching
#     Fetching @python_system; fetching
# Analyzing: target //python/pip_package:build_pip_package (15 packages loaded, \
# 42 targets configured)
#     Fetching @local_config_cc; fetching
# Analyzing: target //python/pip_package:build_pip_package (16 packages loaded, \
# 42 targets configured)
#     Fetching @local_config_cc; fetching
# Analyzing: target //python/pip_package:build_pip_package (16 packages loaded, \
# 42 targets configured)
# Analyzing: target //python/pip_package:build_pip_package (22 packages loaded, \
# 257 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
# Analyzing: target //python/pip_package:build_pip_package (22 packages loaded, \
# 278 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching https://mirror.bazel.build/.../glib/2.55/glib-2.55.1.tar.xz
# Analyzing: target //python/pip_package:build_pip_package (23 packages loaded, \
# 664 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching https://mirror.bazel.build/.../2.55/glib-2.55.1.tar.xz; 73,787B
# Analyzing: target //python/pip_package:build_pip_package (24 packages loaded, \
# 1527 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching https://mirror.bazel.build/.../2.55/glib-2.55.1.tar.xz; 274,491B
#     Fetching @zlib_archive; fetching
# Analyzing: target //python/pip_package:build_pip_package (24 packages loaded, \
# 2043 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching https://mirror.bazel.build/.../2.55/glib-2.55.1.tar.xz; 883,417B
#     Fetching @zlib_archive; fetching
# Analyzing: target //python/pip_package:build_pip_package (24 packages loaded, \
# 2044 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching https://mirror.bazel.build/.../glib-2.55.1.tar.xz; 2,300,633B
#     Fetching @zlib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching https://github.com/abseil/abseil-cpp/archive/master.zip
#     Fetching https://mirror.bazel.build/zlib.net/zlib-1.2.11.tar.gz
# Analyzing: target //python/pip_package:build_pip_package (24 packages loaded, \
# 2044 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching https://mirror.bazel.build/.../glib-2.55.1.tar.xz; 5,201,895B
#     Fetching @zlib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching https://github.com/.../abseil-cpp/archive/master.zip; 515,984B
#     Fetching https://mirror.bazel.build/zlib.net/zlib-1.2.11.tar.gz; 49,207B
# INFO: SHA256 (https://github.com/abseil/abseil-cpp/archive/master.zip) = 4d78092bb7743586a015fa0d66e408411c99ff4a72d0b0c099047b1fa01dcbd3
# Analyzing: target //python/pip_package:build_pip_package (24 packages loaded, \
# 2044 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching @zlib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching https://mirror.bazel.build/zlib.net/zlib-1.2.11.tar.gz; 73,783B
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
# Analyzing: target //python/pip_package:build_pip_package (24 packages loaded, \
# 2044 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching @zlib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching https://mirror.bazel.build/zlib.net/zlib-1.2.11.tar.gz; 213,047B
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching ...e_absl; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/com_google_absl/temp5530079340465490812/master.z\
# ip
# Analyzing: target //python/pip_package:build_pip_package (24 packages loaded, \
# 2044 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching @zlib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching ...e_absl; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/com_google_absl/temp5530079340465490812/master.z\
# ip
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/zlib_archive/temp17762079258749746065/zlib-1.2.1\
# 1.tar.gz
# Analyzing: target //python/pip_package:build_pip_package (25 packages loaded, \
# 2158 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @com_google_absl; fetching
#     Fetching @png_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching ...e_absl; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/com_google_absl/temp5530079340465490812/master.z\
# ip
# DEBUG: Rule 'com_google_absl' indicated that a canonical reproducible form can be obtained by modifying arguments sha256 = "4d78092bb7743586a015fa0d66e408411c99ff4a72d0b0c099047b1fa01dcbd3"
# Analyzing: target //python/pip_package:build_pip_package (25 packages loaded, \
# 2159 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching https://github.com/glennrp/libpng/archive/v1.6.37.zip
#     Fetching @jpeg_archive; fetching
# DEBUG: Repository com_google_absl instantiated at:
#   /kaggle/working/leco/leco/lab/WORKSPACE:18:13: in <toplevel>
# Repository rule http_archive defined at:
#   /root/.cache/bazel/_bazel_root/bbd565e0deb94ba93b80125a9d5a296f/external/bazel_tools/tools/build_defs/repo/http.bzl:336:31: in <toplevel>
# Analyzing: target //python/pip_package:build_pip_package (25 packages loaded, \
# 2159 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching https://github.com/glennrp/libpng/archive/v1.6.37.zip
#     Fetching @jpeg_archive; fetching
# Analyzing: target //python/pip_package:build_pip_package (31 packages loaded, \
# 2163 targets configured)
#     currently loading: @com_google_absl//absl
#     Fetching @glib_archive; fetching
#     Fetching @png_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @bazel_skylib; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/png_archive/temp14914993889311985264/v1.6.37.zip
# WARNING: Download from https://mirror.bazel.build/github.com/glennrp/libpng/archive/v1.6.37.zip failed: class com.google.devtools.build.lib.bazel.repository.downloader.UnrecoverableHttpException GET returned 404 Not Found
# Analyzing: target //python/pip_package:build_pip_package (31 packages loaded, \
# 2163 targets configured)
#     currently loading: @com_google_absl//absl
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @bazel_skylib; fetching
# Analyzing: target //python/pip_package:build_pip_package (32 packages loaded, \
# 2163 targets configured)
#     currently loading: @com_google_absl//absl
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @bazel_skylib; fetching
#     Fetching @libxml_archive; fetching
#     Fetching http://www.ijg.org/files/jpegsrc.v9d.tar.gz
# Analyzing: target //python/pip_package:build_pip_package (32 packages loaded, \
# 2163 targets configured)
#     currently loading: @com_google_absl//absl
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @bazel_skylib; fetching
#     Fetching @libxml_archive; fetching
#     Fetching http://www.ijg.org/files/jpegsrc.v9d.tar.gz
#     Fetching https://mirror.bazel.build/.../sources/libxml2-2.9.7.tar.gz
# INFO: SHA256 (https://github.com/bazelbuild/bazel-skylib/archive/main.zip) = 5343fd7909e3979efdee996213b6593ce9d5bb6e65696b194d9e98b6b90823e2
# Analyzing: target //python/pip_package:build_pip_package (32 packages loaded, \
# 2163 targets configured)
#     currently loading: @com_google_absl//absl
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @bazel_skylib; fetching
#     Fetching @libxml_archive; fetching
#     Fetching http://www.ijg.org/files/jpegsrc.v9d.tar.gz
#     Fetching https://mirror.bazel.build/.../sources/libxml2-2.9.7.tar.gz
# DEBUG: Rule 'bazel_skylib' indicated that a canonical reproducible form can be obtained by modifying arguments sha256 = "5343fd7909e3979efdee996213b6593ce9d5bb6e65696b194d9e98b6b90823e2"
# Analyzing: target //python/pip_package:build_pip_package (32 packages loaded, \
# 2163 targets configured)
#     currently loading: @com_google_absl//absl
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @libxml_archive; fetching
#     Fetching http://www.ijg.org/files/jpegsrc.v9d.tar.gz; 17,102B
#     Fetching https://mirror.bazel.build/.../libxml2-2.9.7.tar.gz; 90,171B
# DEBUG: Repository bazel_skylib instantiated at:
#   /kaggle/working/leco/leco/lab/WORKSPACE:12:13: in <toplevel>
# Repository rule http_archive defined at:
#   /root/.cache/bazel/_bazel_root/bbd565e0deb94ba93b80125a9d5a296f/external/bazel_tools/tools/build_defs/repo/http.bzl:336:31: in <toplevel>
# Analyzing: target //python/pip_package:build_pip_package (32 packages loaded, \
# 2163 targets configured)
#     currently loading: @com_google_absl//absl
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @libxml_archive; fetching
#     Fetching http://www.ijg.org/files/jpegsrc.v9d.tar.gz; 17,102B
#     Fetching https://mirror.bazel.build/.../libxml2-2.9.7.tar.gz; 90,171B
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @libxml_archive; fetching
#     Fetching http://www.ijg.org/files/jpegsrc.v9d.tar.gz; 46,062B
#     Fetching https://mirror.bazel.build/.../libxml2-2.9.7.tar.gz; 1,194,702B
# ERROR: /root/.cache/bazel/_bazel_root/bbd565e0deb94ba93b80125a9d5a296f/external/com_google_absl/absl/BUILD.bazel:109:15: no such target '@platforms//cpu:wasm32': target 'wasm32' not declared in package 'cpu' defined by /root/.cache/bazel/_bazel_root/bbd565e0deb94ba93b80125a9d5a296f/external/platforms/cpu/BUILD and referenced by '@com_google_absl//absl:platforms_wasm32'
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @libxml_archive; fetching
#     Fetching http://www.ijg.org/files/jpegsrc.v9d.tar.gz; 77,918B
#     Fetching https://mirror.bazel.build/.../libxml2-2.9.7.tar.gz; 1,194,702B
# INFO: Repository libxml_archive instantiated at:
#   /kaggle/working/leco/leco/lab/WORKSPACE:79:13: in <toplevel>
# Repository rule http_archive defined at:
#   /root/.cache/bazel/_bazel_root/bbd565e0deb94ba93b80125a9d5a296f/external/bazel_tools/tools/build_defs/repo/http.bzl:336:31: in <toplevel>
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
#     Fetching @libxml_archive; fetching
# INFO: Repository jpeg_archive instantiated at:
#   /kaggle/working/leco/leco/lab/WORKSPACE:71:13: in <toplevel>
# Repository rule http_archive defined at:
#   /root/.cache/bazel/_bazel_root/bbd565e0deb94ba93b80125a9d5a296f/external/bazel_tools/tools/build_defs/repo/http.bzl:336:31: in <toplevel>
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
#     Fetching @jpeg_archive; fetching
# ERROR: While resolving configuration keys for @com_google_absl//absl:wasm_3: Analysis failed
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
# ERROR: While resolving configuration keys for @com_google_absl//absl/base:base: Analysis failed
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
# ERROR: Analysis of target '//python/pip_package:build_pip_package' failed; build aborted: Analysis failed
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
# INFO: Elapsed time: 11.638s
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
# INFO: 0 processes.
# Analyzing: target //python/pip_package:build_pip_package (38 packages loaded, \
# 2251 targets configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
# FAILED: Build did NOT complete successfully (38 packages loaded, 2251 targets \
# configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz
# FAILED: Build did NOT complete successfully (38 packages loaded, 2251 targets \
# configured)
#     Fetching @glib_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/bbd565e0deb9\
# 4ba93b80125a9d5a296f/external/glib_archive/temp14334630852037082365/glib-2.55.\
# 1.tar.xz

# %%
# !ls
# Out:
# BUILD		  WORKSPACE  deepmind	game_scripts	   q3map2
# CONTRIBUTING	  assets     dmlab.lds	lua_tests	   testing
# LICENSE		  assets_oa  docs	public		   third_party
# README.md	  bazel      engine	python
# RELEASE_NOTES.md  data	     examples	python_system.bzl

# %%
# !./bazel-bin/python/pip_package/build_pip_package /tmp/tensorflow_pkg

# Install the wheel file
# !pip install /tmp/tensorflow_pkg/tensorflow-*.whl
# Out:
# /bin/bash: ./bazel-bin/python/pip_package/build_pip_package: No such file or directory
# WARNING: Requirement '/tmp/tensorflow_pkg/tensorflow-*.whl' looks like a filename, but the file does not exist
# ERROR: tensorflow-*.whl is not a valid wheel filename.

# %%
# %cd /content/leco
# Out:
# [Errno 2] No such file or directory: '/content/leco'
# /kaggle/working/leco/leco/lab

# %%
# !pip install colorlog
# Out:
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (6.8.2)

# %%
# !pip install tensorboardX
# Out:
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.1)

# %%
# !pip install torch_optimizer
# Out:
# Collecting torch_optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from torch_optimizer) (2.1.2+cpu)
# Collecting pytorch-ranger>=0.1.1 (from torch_optimizer)
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl.metadata (509 bytes)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.5.0->torch_optimizer) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.5.0->torch_optimizer) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.5.0->torch_optimizer) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.5.0->torch_optimizer) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.5.0->torch_optimizer) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.5.0->torch_optimizer) (2024.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.5.0->torch_optimizer) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.5.0->torch_optimizer) (1.3.0)
# Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 2.0 MB/s eta 0:00:00
# Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Installing collected packages: pytorch-ranger, torch_optimizer
# Successfully installed pytorch-ranger-0.1.1 torch_optimizer-0.3.0

# %%
# !pip install faster_fifo
# Out:
# Collecting faster_fifo
#   Downloading faster_fifo-1.4.7.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.6/112.6 kB 2.3 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=45.2.0 in /opt/conda/lib/python3.10/site-packages (from faster_fifo) (69.0.3)
# Requirement already satisfied: cython>=0.29 in /opt/conda/lib/python3.10/site-packages (from faster_fifo) (3.0.8)
# Building wheels for collected packages: faster_fifo
#   Building wheel for faster_fifo (pyproject.toml) ... done
#   Created wheel for faster_fifo: filename=faster_fifo-1.4.7-cp310-cp310-linux_x86_64.whl size=94680 sha256=d13f00fc40706957f564653c82d730150ee8feeb1715df6b6589dc526f0183ac
#   Stored in directory: /root/.cache/pip/wheels/bc/66/d1/e4d2eb7b7a15fb57371c07f8298acfa1b528d05618f5e1d91d
# Successfully built faster_fifo
# Installing collected packages: faster_fifo
# Successfully installed faster_fifo-1.4.7

# %%
# !pip install py3nvml
# Out:
# Collecting py3nvml
#   Downloading py3nvml-0.2.7-py3-none-any.whl.metadata (13 kB)
# Collecting xmltodict (from py3nvml)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Downloading py3nvml-0.2.7-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.8 MB/s eta 0:00:00
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict, py3nvml
# Successfully installed py3nvml-0.2.7 xmltodict-0.13.0

# %%
import os
os.environ['WORLD_SIZE'] = '1'  # Set WORLD_SIZE to 0

# %%
# !python -m dist.launch --master_addr=$MASTER_ADDR -m sample_factory.algorithms.appo.train_appo --cfg=lstm_MiniGrid-ObstructedMaze-Full_leco --train_dir=/content/leco/train --experiment=your_experiment_name
# Out:
# /opt/conda/bin/python: Error while finding module specification for 'dist.launch' (ModuleNotFoundError: No module named 'dist')

# %%
#!python3 -u -m sample_factory.algorithms.appo.train_appo \
 #   --nproc_per_node=1 \
  #  --cfg=lstm_MiniGrid-ObstructedMaze-Full_leco \
   # --train_dir=/content/leco/train \
    #--experiment=your_experiment_name

# %%
#!python -m dist.launch --nnodes=1 --node_rank=0 --nproc_per_node=2 --master_addr=$MASTER_ADDR -m sample_factory.algorithms.appo.train_appo --cfg=lstm_MiniGrid-ObstructedMaze-Full_leco --train_dir=/content/leco/train --experiment=your_experiment_name
